# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("city_day.csv")

# %%
df
# Out:
#                      City        Date  PM2.5   PM10    NO    NO2    NOx   NH3  \
# 0               Ahmedabad  2015-01-01    NaN    NaN   NaN  18.22  17.15   NaN
# 1               Ahmedabad  2015-01-02    NaN    NaN   NaN  15.69  16.46   NaN
# 2               Ahmedabad  2015-01-03    NaN    NaN   NaN  19.30  29.70   NaN
# 3               Ahmedabad  2015-01-04    NaN    NaN   NaN  18.48  17.97   NaN
# 4               Ahmedabad  2015-01-05    NaN    NaN   NaN  21.42  37.76   NaN
# ...                   ...         ...    ...    ...   ...    ...    ...   ...
# 25550  Thiruvananthapuram  2020-04-06  16.88  31.28  4.32  10.18  13.71  5.55
# 25551  Thiruvananthapuram  2020-04-07  18.57  35.34  5.70   9.56  12.70  4.97
# 25552  Thiruvananthapuram  2020-04-08  18.85  37.62  5.44   8.86  12.09  4.39
# 25553  Thiruvananthapuram  2020-04-09  19.06  45.18  3.37   7.91   9.92  4.37
# 25554  Thiruvananthapuram  2020-04-10  23.44  42.10  2.84   7.18   8.93  3.49
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25555 entries, 0 to 25554
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        25555 non-null  object
#  1   Date        25555 non-null  object
#  2   PM2.5       21300 non-null  float64
#  3   PM10        14853 non-null  float64
#  4   NO          21046 non-null  float64
#  5   NO2         22396 non-null  float64
#  6   NOx         21534 non-null  float64
#  7   NH3         15770 non-null  float64
#  8   CO          23556 non-null  float64
#  9   SO2         22056 non-null  float64
#  10  O3          22045 non-null  float64
#  11  Benzene     20433 non-null  float64
#  12  Toluene     18146 non-null  float64
#  13  Xylene      9138 non-null   float64
#  14  AQI         21304 non-null  float64
#  15  AQI_Bucket  21304 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.1+ MB

# %%
df.isnull()
# Out:
#         City   Date  PM2.5   PM10     NO    NO2    NOx    NH3     CO    SO2  \
# 0      False  False   True   True   True  False  False   True  False  False
# 1      False  False   True   True   True  False  False   True  False  False
# 2      False  False   True   True   True  False  False   True  False  False
# 3      False  False   True   True   True  False  False   True  False  False
# 4      False  False   True   True   True  False  False   True  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 25550  False  False  False  False  False  False  False  False  False  False
# 25551  False  False  False  False  False  False  False  False  False  False
# 25552  False  False  False  False  False  False  False  False  False  False
# 25553  False  False  False  False  False  False  False  False  False  False
# 25554  False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
df.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4255
# PM10          10702
# NO             4509
# NO2            3159
# NOx            4021
# NH3            9785
# CO             1999
# SO2            3499
# O3             3510
# Benzene        5122
# Toluene        7409
# Xylene        16417
# AQI            4251
# AQI_Bucket     4251
# dtype: int64

# %%
df2 = df.copy()

# %%
df2
# Out:
#                      City        Date  PM2.5   PM10    NO    NO2    NOx   NH3  \
# 0               Ahmedabad  2015-01-01    NaN    NaN   NaN  18.22  17.15   NaN
# 1               Ahmedabad  2015-01-02    NaN    NaN   NaN  15.69  16.46   NaN
# 2               Ahmedabad  2015-01-03    NaN    NaN   NaN  19.30  29.70   NaN
# 3               Ahmedabad  2015-01-04    NaN    NaN   NaN  18.48  17.97   NaN
# 4               Ahmedabad  2015-01-05    NaN    NaN   NaN  21.42  37.76   NaN
# ...                   ...         ...    ...    ...   ...    ...    ...   ...
# 25550  Thiruvananthapuram  2020-04-06  16.88  31.28  4.32  10.18  13.71  5.55
# 25551  Thiruvananthapuram  2020-04-07  18.57  35.34  5.70   9.56  12.70  4.97
# 25552  Thiruvananthapuram  2020-04-08  18.85  37.62  5.44   8.86  12.09  4.39
# 25553  Thiruvananthapuram  2020-04-09  19.06  45.18  3.37   7.91   9.92  4.37
# 25554  Thiruvananthapuram  2020-04-10  23.44  42.10  2.84   7.18   8.93  3.49
#
# ...

# %%
df2 = df2.fillna(df2.mean())
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11352\239559528.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2 = df2.fillna(df2.mean())

# %%
df2
# Out:
#        City        Date      PM2.5        PM10         NO    NO2    NOx  \
# 0         6  2015-01-01  72.824121  127.653183  17.658008  18.22  17.15
# 1         6  2015-01-02  72.824121  127.653183  17.658008  15.69  16.46
# 2         6  2015-01-03  72.824121  127.653183  17.658008  19.30  29.70
# 3         6  2015-01-04  72.824121  127.653183  17.658008  18.48  17.97
# 4         6  2015-01-05  72.824121  127.653183  17.658008  21.42  37.76
# ...     ...         ...        ...         ...        ...    ...    ...
# 25550     7  2020-04-06  16.880000   31.280000   4.320000  10.18  13.71
# 25551     7  2020-04-07  18.570000   35.340000   5.700000   9.56  12.70
# 25552     7  2020-04-08  18.850000   37.620000   5.440000   8.86  12.09
# 25553     7  2020-04-09  19.060000   45.180000   3.370000   7.91   9.92
# 25554     7  2020-04-10  23.440000   42.100000   2.840000   7.18   8.93
#
#             NH3     CO    SO2      O3   Benzene    Toluene   Xylene  \
# ...

# %%
df2
# Out:
#        City        Date      PM2.5        PM10         NO    NO2    NOx  \
# 0         6  2015-01-01  72.824121  127.653183  17.658008  18.22  17.15
# 1         6  2015-01-02  72.824121  127.653183  17.658008  15.69  16.46
# 2         6  2015-01-03  72.824121  127.653183  17.658008  19.30  29.70
# 3         6  2015-01-04  72.824121  127.653183  17.658008  18.48  17.97
# 4         6  2015-01-05  72.824121  127.653183  17.658008  21.42  37.76
# ...     ...         ...        ...         ...        ...    ...    ...
# 25550     7  2020-04-06  16.880000   31.280000   4.320000  10.18  13.71
# 25551     7  2020-04-07  18.570000   35.340000   5.700000   9.56  12.70
# 25552     7  2020-04-08  18.850000   37.620000   5.440000   8.86  12.09
# 25553     7  2020-04-09  19.060000   45.180000   3.370000   7.91   9.92
# 25554     7  2020-04-10  23.440000   42.100000   2.840000   7.18   8.93
#
#             NH3     CO    SO2      O3   Benzene    Toluene   Xylene  \
# ...

# %%
dist = df2['City']
dset = set(dist)
dlist = list(dset)
dictCity = {dlist[i] : i for i in range(0,len(dlist))}
df2['City'] = df2['City'].map(dictCity)

# %%
df2
# Out:
#        City        Date      PM2.5        PM10         NO    NO2    NOx  \
# 0         6  2015-01-01  72.824121  127.653183  17.658008  18.22  17.15
# 1         6  2015-01-02  72.824121  127.653183  17.658008  15.69  16.46
# 2         6  2015-01-03  72.824121  127.653183  17.658008  19.30  29.70
# 3         6  2015-01-04  72.824121  127.653183  17.658008  18.48  17.97
# 4         6  2015-01-05  72.824121  127.653183  17.658008  21.42  37.76
# ...     ...         ...        ...         ...        ...    ...    ...
# 25550     7  2020-04-06  16.880000   31.280000   4.320000  10.18  13.71
# 25551     7  2020-04-07  18.570000   35.340000   5.700000   9.56  12.70
# 25552     7  2020-04-08  18.850000   37.620000   5.440000   8.86  12.09
# 25553     7  2020-04-09  19.060000   45.180000   3.370000   7.91   9.92
# 25554     7  2020-04-10  23.440000   42.100000   2.840000   7.18   8.93
#
#             NH3     CO    SO2      O3   Benzene    Toluene   Xylene  \
# ...

# %%
dist = (df2['AQI_Bucket'])
dset = set(dist)
dlist = list(dset)
dictOfAqi = {dlist[i] : i for i in range(0,len(dlist))}
df2['AQI_Bucket'] = df2['AQI_Bucket'].map(dictOfAqi)

# %%
df2
# Out:
#        City        Date      PM2.5        PM10         NO    NO2    NOx  \
# 0         6  2015-01-01  72.824121  127.653183  17.658008  18.22  17.15
# 1         6  2015-01-02  72.824121  127.653183  17.658008  15.69  16.46
# 2         6  2015-01-03  72.824121  127.653183  17.658008  19.30  29.70
# 3         6  2015-01-04  72.824121  127.653183  17.658008  18.48  17.97
# 4         6  2015-01-05  72.824121  127.653183  17.658008  21.42  37.76
# ...     ...         ...        ...         ...        ...    ...    ...
# 25550     7  2020-04-06  16.880000   31.280000   4.320000  10.18  13.71
# 25551     7  2020-04-07  18.570000   35.340000   5.700000   9.56  12.70
# 25552     7  2020-04-08  18.850000   37.620000   5.440000   8.86  12.09
# 25553     7  2020-04-09  19.060000   45.180000   3.370000   7.91   9.92
# 25554     7  2020-04-10  23.440000   42.100000   2.840000   7.18   8.93
#
#             NH3     CO    SO2      O3   Benzene    Toluene   Xylene  \
# ...

# %%
df2['AQI_Bucket'] = df2['AQI_Bucket'].fillna(df2['AQI_Bucket'].mean())

# %%
df2
# Out:
#        City        Date      PM2.5        PM10         NO    NO2    NOx  \
# 0         6  2015-01-01  72.824121  127.653183  17.658008  18.22  17.15
# 1         6  2015-01-02  72.824121  127.653183  17.658008  15.69  16.46
# 2         6  2015-01-03  72.824121  127.653183  17.658008  19.30  29.70
# 3         6  2015-01-04  72.824121  127.653183  17.658008  18.48  17.97
# 4         6  2015-01-05  72.824121  127.653183  17.658008  21.42  37.76
# ...     ...         ...        ...         ...        ...    ...    ...
# 25550     7  2020-04-06  16.880000   31.280000   4.320000  10.18  13.71
# 25551     7  2020-04-07  18.570000   35.340000   5.700000   9.56  12.70
# 25552     7  2020-04-08  18.850000   37.620000   5.440000   8.86  12.09
# 25553     7  2020-04-09  19.060000   45.180000   3.370000   7.91   9.92
# 25554     7  2020-04-10  23.440000   42.100000   2.840000   7.18   8.93
#
#             NH3     CO    SO2      O3   Benzene    Toluene   Xylene  \
# ...

# %%
df2.isna().sum()
# Out:
# City          0
# Date          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI           0
# AQI_Bucket    0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# City          0
# Date          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI           0
# AQI_Bucket    0
# dtype: int64

# %%
df2 = df2.drop('Date')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 df2 = df2.drop('Date')
#
# File C:\Python 3.10\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\Python 3.10\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
# ...

# %%
df2
# Out:
#        City        Date      PM2.5        PM10         NO    NO2    NOx  \
# 0         6  2015-01-01  72.824121  127.653183  17.658008  18.22  17.15
# 1         6  2015-01-02  72.824121  127.653183  17.658008  15.69  16.46
# 2         6  2015-01-03  72.824121  127.653183  17.658008  19.30  29.70
# 3         6  2015-01-04  72.824121  127.653183  17.658008  18.48  17.97
# 4         6  2015-01-05  72.824121  127.653183  17.658008  21.42  37.76
# ...     ...         ...        ...         ...        ...    ...    ...
# 25550     7  2020-04-06  16.880000   31.280000   4.320000  10.18  13.71
# 25551     7  2020-04-07  18.570000   35.340000   5.700000   9.56  12.70
# 25552     7  2020-04-08  18.850000   37.620000   5.440000   8.86  12.09
# 25553     7  2020-04-09  19.060000   45.180000   3.370000   7.91   9.92
# 25554     7  2020-04-10  23.440000   42.100000   2.840000   7.18   8.93
#
#             NH3     CO    SO2      O3   Benzene    Toluene   Xylene  \
# ...

# %%
df2 = df2.drop('Date',1)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11352\3045231354.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df2 = df2.drop('Date',1)

# %%
import plotly.express as px

# %%
fig = px.scatter(df, x='City', y = 'AQI')

# %%
fig.show()
# Out:
# <div>                            <div id="5ee158f9-629d-4231-8dde-862c912df0c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ee158f9-629d-4231-8dde-862c912df0c3")) {                    Plotly.newPlot(                        "5ee158f9-629d-4231-8dde-862c912df0c3",                        [{"hovertemplate":"City=%{x}<br>AQI=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":["Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedab
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
x = df[['NO2','SO2','O3']]
y = df['City']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)

# %%
predictions = model.predict(x_test)

# %%
predictions

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model2 = RandomForestRegressor()

# %%
model2.fit(x,y)

# %%
predictons = model.predict(x_test)

# %%
predictons

# %%
from sklearn.metrics import r2_score
y_pred = model2.predict(x_test)

# %%
r2_score(y_test, y_pred)
